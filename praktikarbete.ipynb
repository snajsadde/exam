# %%
from skimage.data import *
import numpy as np
from skimage import io
from skimage.filters import gaussian

# %%
m = moon()
j2 = moon()

# %%
from matplotlib import pyplot as plt

# %%
def p(img):
    plt.imshow(img)
    plt.show()
    
def h(img, bins=256):
    plt.hist(img.flatten(), bins=bins, fc='k', ec='k')
    plt.show()
    
def red(img):
    return img[:,:,0]
def green(img):
    return img[:,:,1]

# %%
p(m)

# %%
m.shape
# Out:
# (512, 512)

# %%
m3 = np.dstack([m,m,m])

# %%
p(m3)

# %%
b = io.imread('/home/andreas/Downloads/human.jpg')
p(b)

# %%
a = astronaut()

# %%
p(a)

# %%
a.shape
# Out:
# (512, 512, 3)

# %%
m3.shape
# Out:
# (512, 512, 3)

# %%
p(2*m3)

# %%
p(m3)

# %%
h(a)

# %%
h(red(a)); h(m)

# %%
h(b)

# %%
p(b*(b<180))
